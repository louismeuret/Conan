# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter
import os,shutil,math,statistics
from lxml import etree
root = etree.parse("/home/louis/SBVS/results/XML/output.xml")
good = []
distrib1 = []
distrib2 = []
distancetotal = []
kmeanarray = np.array([[0, 0, 0], [0, 0, 0]])

coordxfmn = 269.807
coordyfmn = 257.777
coordzfmn = 280.718
distancecalc = []
def distance(x1,y1,z1,x2,y2,z2):
    d = math.sqrt(pow(x2 - x1, 2) +
                pow(y2 - y1, 2) +
                pow(z2 - z1, 2) * 1.0);
    return d
 
for x in range(1,1000):
    name = "outputfile"+str(x)
    #try:
    count = 0
    for a in root.findall(name):
        
        value = float(a.find('energy').text)
        distrib1.append(value)
        vardist = distance(coordxfmn,coordyfmn,coordzfmn,float(a.find('coordx').text),float(a.find('coordy').text),float(a.find('coordz').text))
        nomligand = a.find('nomligand').text
        bestligandinput = "/home/louis/SBVS/results/BEST/"+nomligand+".pdbqt"
        bestligandoutput = "/home/louis/SBVS/Analysis/temp/"+nomligand+".pdb"
        
        #m = Chem.MolFromPDBFile(bestligandinput,sanitize=False)
        #logp = Chem.Crippen.MolLogP(m)
        #kmeanarray = numpy.append(kmeanarray, [[value, vardist,logp]], axis = 0)
        count = count + 1
        distancetotal.append(vardist)
        if value > -9:
            good.append(nomligand)
            obabel = "obabel -ipdbqt "+bestligandinput+" -opdbqt -O"+bestligandoutput
            os.system(obabel)
            distancecalc.append(vardist)
print(kmeanarray)
print(distancetotal)
print(statistics.mean(distancecalc))
# Out:
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is outputfile226.pdb)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is outputfile239.pdb)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is outputfile286.pdb)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is outputfile327.pdb)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is outputfile334.pdb)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is outputfile374.pdb)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is outputfile480.pdb)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is outputfile514.pdb)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is outputfile656.pdb)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is outputfile760.pdb)
#
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is outputfile761.pdb)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# [[0 0 0]
#  [0 0 0]]
# [22.092963227858277, 23.198150659050388, 9.35469289833833, 15.431712996294406, 22.700464444587915, 9.390285859898606, 9.230128914472289, 10.032757853558902, 9.743269684698319, 22.72232120625002, 22.44686245057422, 8.5052953309493, 9.770105478576026, 9.153052928852087, 22.441636348537532, 9.347750053488816, 23.15928002196536, 8.964877008513701, 9.67549327553898, 15.220701692914531, 8.789540994209531, 8.94782664068972, 6.588411839846408, 9.149708519947529, 9.856523027798891, 22.586590198939138, 23.562653185178405, 15.258127317014424, 9.780865043542997, 21.928754623903558, 6.106404512810617, 9.112452119635748, 9.606103256668515, 9.419347112443145, 23.35395418077099, 23.192364189402486, 9.422615703057238, 9.255598447696425, 23.343903123094204, 8.244444595453379, 9.829133329037768, 8.75060307564575, 8.835713779882205, 22.913468901544324, 9.337314518005936, 22.75956203534715, 22.58652172341945, 9.20399577880699, 9.009606494597863, 8.993133620296105, 9.398265704373353, 8.30401771821713, 22.215780170016544, 23.989135023745625, 8.635179066481745, 8.748442850730646, 22.776568508456414, 6.185828648006651, 9.153222065890231, 23.146932183336954, 9.333684284920913, 23.236930519308757, 8.72223760711665, 8.903964993880205, 8.736364884078219, 22.751866071931403, 9.220295351831204, 9
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted

# %%
plt.figure(1)
plt.hist(distrib1, bins=20)
# Out:
# (array([  2.,   5.,   7.,  17.,  48.,  87., 137., 150., 131., 137.,  87.,
#          52.,  41.,  28.,  13.,   4.,   3.,   3.,   0.,   1.]),
#  array([-8.37 , -8.127, -7.884, -7.641, -7.398, -7.155, -6.912, -6.669,
#         -6.426, -6.183, -5.94 , -5.697, -5.454, -5.211, -4.968, -4.725,
#         -4.482, -4.239, -3.996, -3.753, -3.51 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.figure(2)
plt.hist(distancetotal, bins=20)
# Out:
# (array([ 64.,  84.,  14., 190., 307.,  24.,   0.,   0.,   0.,   0.,   2.,
#           1.,   0.,   0.,   3.,   3.,   1.,   7., 126., 127.]),
#  array([ 4.70061027,  5.66372397,  6.62683767,  7.58995137,  8.55306507,
#          9.51617877, 10.47929248, 11.44240618, 12.40551988, 13.36863358,
#         14.33174728, 15.29486098, 16.25797469, 17.22108839, 18.18420209,
#         19.14731579, 20.11042949, 21.07354319, 22.03665689, 22.9997706 ,
#         23.9628843 ]),
#  <BarContainer object of 20 artists>)

# %%
plt.figure(3)
plt.scatter(distancetotal, distrib1)

# %%
import os,shutil,math,statistics
from lxml import etree
root = etree.parse("/home/louis/SBVS/results/XML/output2.xml")
good = []
distrib1 = []
distrib2 = []

coordxfmn = 269.807
coordyfmn = 257.777
coordzfmn = 280.718
distancecalc = []
def distance(x1,y1,z1,x2,y2,z2):
    d = math.sqrt(pow(x2 - x1, 2) +
                pow(y2 - y1, 2) +
                pow(z2 - z1, 2) * 1.0);
    return d
 
for x in range(2,2000):
    name = "outputfile"+str(x)
    #try:
    for a in root.findall(name):
        value = float(a.find('energy').text)
        distrib1.append(value)
        if value < -8:
            nomligand = a.find('nomligand').text
            good.append(nomligand)
            bestligandinput = "/home/louis/SBVS/results/BEST/"+nomligand+".pdbqt"
            bestligandoutput = "/home/louis/SBVS/Analysis/temp/"+nomligand+".pdb"
            obabel = "obabel -ipdbqt "+bestligandinput+" -opdbqt -O"+bestligandoutput
            os.system(obabel)
            distancecalc.append(distance(coordxfmn,coordyfmn,coordzfmn,float(a.find('coordx').text),float(a.find('coordy').text),float(a.find('coordz').text)))

plt.hist(distrib1, bins=20)
print(statistics.mean(distancecalc))
# Out:
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 6.854243424162559
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted

# %%
import os,shutil,math,statistics
from lxml import etree
root = etree.parse("/home/louis/SBVS/results/XML/output2.xml")
good = []
distrib1 = []
distrib2 = []

coordxfmn = 269.807
coordyfmn = 257.777
coordzfmn = 280.718
distancecalc = []
def distance(x1,y1,z1,x2,y2,z2):
    d = math.sqrt(pow(x2 - x1, 2) +
                pow(y2 - y1, 2) +
                pow(z2 - z1, 2) * 1.0);
    return d
 
for x in range(2,2000):
    name = "outputfile"+str(x)
    #try:
    for a in root.findall(name):
        value = float(a.find('energy').text)
        distrib1.append(value)
        if value > -5:
            nomligand = a.find('nomligand').text
            good.append(nomligand)
            bestligandinput = "/home/louis/SBVS/results/BEST/"+nomligand+".pdbqt"
            bestligandoutput = "/home/louis/SBVS/Analysis/smartn/"+nomligand+".mol2"
            obabel = "obabel -ipdbqt "+bestligandinput+" -omol2 -O"+bestligandoutput
            os.system(obabel)
            distancecalc.append(distance(coordxfmn,coordyfmn,coordzfmn,float(a.find('coordx').text),float(a.find('coordy').text),float(a.find('coordz').text)))

plt.hist(distrib1, bins=20)
print(statistics.mean(distancecalc))
# Out:
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 15.184412021594628

# %%
import os,shutil,math,statistics
from lxml import etree
root = etree.parse("/home/louis/SBVS/results/XML/output.xml")
good = []
distrib1 = []
distrib2 = []

coordxfmn = 269.807
coordyfmn = 257.777
coordzfmn = 280.718
distancecalc = []
def distance(x1,y1,z1,x2,y2,z2):
    d = math.sqrt(pow(x2 - x1, 2) +
                pow(y2 - y1, 2) +
                pow(z2 - z1, 2) * 1.0);
    return d
 
for x in range(2000,12000):
    name = "outputfile"+str(x)
    #try:
    for a in root.findall(name):
        value = float(a.find('energy').text)
        distrib1.append(value)
        if value < -10:
            nomligand = a.find('nomligand').text
            good.append(nomligand)
            bestligandinput = "/home/louis/SBVS/results/BEST/"+nomligand+".pdbqt"
            bestligandoutput = "/home/louis/SBVS/Analysis/smartp/"+nomligand+".mol"
            obabel = "obabel -ipdbqt "+bestligandinput+" -omol -O"+bestligandoutput
            os.system(obabel)
            distancecalc.append(distance(coordxfmn,coordyfmn,coordzfmn,float(a.find('coordx').text),float(a.find('coordy').text),float(a.find('coordz').text)))

plt.hist(distrib1, bins=20)
print(statistics.mean(distancecalc))
# Out:
# 1 molecule converted
# ==============================
# *** Open Babel Warning  in PerceiveBondOrders
#   Failed to kekulize aromatic bonds in OBMol::PerceiveBondOrders (title is outputfile6789.pdb)
#
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 1 molecule converted
# 6.080444848011682

# %%
from rdkit.Chem import rdFMCS
from rdkit import Chem

# %%
from rdkit.Chem import rdFMCS

#mol1 = Chem.MolFromMolFile('data/input.mol')
file_names = [fn for fn in os.listdir("/home/louis/SBVS/Analysis/smartp/") if fn.endswith(".mol")]
for x in range(len(file_names)):
    mols.append(Chem.MolFromMolFile(file_names[x]))
    print("ok")
res=rdFMCS.FindMCS(mols)
print(res.smartsString)
res.canceled
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [23], in <cell line: 5>()
#       4 file_names = [fn for fn in os.listdir("/home/louis/SBVS/Analysis/smartp/") if fn.endswith(".mol")]
#       5 for x in range(len(file_names)):
# ----> 6     mols.append(Chem.MolFromMolFile(file_names[x]))
#       7     print("ok")
#       8 res=rdFMCS.FindMCS(mols)
#
# OSError: Bad input file outputfile9059.pdb.mol

# %%
import numpy

a = numpy.array([[0, 0], [0, 0]])

newArray = numpy.append(a, [[value, vardist]], axis = 0)

print(newArray)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [68], in <cell line: 5>()
#       1 import numpy
#       3 a = numpy.array([[], []])
# ----> 5 newArray = numpy.append(a, [[value, vardist]], axis = 0)
#       7 print(newArray)
#
# File <__array_function__ internals>:180, in append(*args, **kwargs)
#
# File ~/pythonenv/env/lib/python3.9/site-packages/numpy/lib/function_base.py:5392, in append(arr, values, axis)
#    5390     values = ravel(values)
#    5391     axis = arr.ndim-1
# -> 5392 return concatenate((arr, values), axis=axis)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 0 and the array at index 1 has size 2
